# %% [markdown]
# <a href="https://colab.research.google.com/github/claycassema22/imersaodados/blob/main/Alura_Aulas_Imers%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EXLORAÇÃO DE DADOS COM PANDAS

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head(20)
# Out:
#     work_year experience_level employment_type           job_title  salary  \
# 0      2025.0               SE              FT  Solutions Engineer  214000
# 1      2025.0               SE              FT  Solutions Engineer  136000
# 2      2025.0               MI              FT       Data Engineer  158800
# 3      2025.0               MI              FT       Data Engineer  139200
# 4      2025.0               EN              FT       Data Engineer   90000
# 5      2025.0               EN              FT       Data Engineer   80000
# 6      2025.0               SE              FT      Data Scientist  185000
# 7      2025.0               SE              FT      Data Scientist  148000
# 8      2025.0               MI              FT      Data Scientist  135000
# 9      2025.0               MI              FT      Data Scientist  108000
# 10     2025.0               MI              FT        BI Developer  118000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print("linhas:", linhas)
print("colunas:", colunas)
# Out:
# linhas: 133349
# colunas: 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.columns = [
    'ano',
    'experiencia',
    'contrato',
    'cargo',
    'salario',
    'moeda',
    'usd',
    'residencia',
    'remoto',
    'empresa',
    'tamanho_empresa'
]
print(df.columns)
# Out:
# Index(['ano', 'experiencia', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df["experiencia"].value_counts()
# Out:
# experiencia
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df["contrato"].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df["remoto"].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
experiencia = {
    'SE': 'Sênior',
    'MI': 'Pleno',
    'EN': 'Júnior',
    'EX': 'Executivo'
}
df['experiencia'] = df['experiencia'].replace(experiencia)
df['experiencia'].value_counts()
# Out:
# experiencia
# Sênior       77241
# pleno        40465
# Júnior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
contrato = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Meio Período',
    'FL': 'Freelance'
}
df['contrato'] = df['contrato'].replace(contrato)
df['contrato'].value_counts()
# Out:
# contrato
# Tempo Integral    132563
# Contrato             394
# Meio Período         376
# Freelance             16
# Name: count, dtype: int64

# %%
tamanho_empresa = {
    'M': 'Médio',
    'L': 'Grande',
    'S': 'Pequeno'
}
df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa)
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# Médio      129561
# Grande       3574
# Pequeno       214
# Name: count, dtype: int64

# %%
df['cargo'].value_counts().head(20)
# Out:
# cargo
# Data Scientist                    17314
# Software Engineer                 15007
# Data Engineer                     14868
# Data Analyst                      12381
# Engineer                           9456
# Machine Learning Engineer          8205
# Manager                            6679
# Analyst                            4364
# Research Scientist                 3202
# Product Manager                    2230
# Applied Scientist                  2205
# Associate                          2073
# Data Architect                     2024
# Analytics Engineer                 1895
# AI Engineer                        1620
# Research Engineer                  1614
# Consultant                         1125
# Data Manager                        975
# Business Intelligence Engineer      870
# Data Specialist                     854
# Name: count, dtype: int64

# %%
remoto = {
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Remoto'
}
df['remoto'] = df['remoto'].replace(remoto)
df['remoto'].value_counts()
# Out:
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano experiencia        contrato               cargo  salario moeda  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df.describe(include="object")
# Out:
#        experiencia        contrato           cargo   moeda residencia  \
# count       133349          133349          133349  133349     133349
# unique           4               4             390      26        102
# top         Sênior  Tempo Integral  Data Scientist     USD         US
# freq         77241          132563           17314  126140     119579
#
#             remoto empresa tamanho_empresa
# count       133349  133349          133349
# unique           3      95               3
# top     Presencial      US           Médio
# freq        105312  119641          129561

# %%
df.describe()
# Out:
#                  ano       salario            usd
# count  133339.000000  1.333490e+05  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098
# std         0.680627  2.173860e+05   74288.363097
# min      2020.000000  1.400000e+04   15000.000000
# 25%      2024.000000  1.060200e+05  106000.000000
# 50%      2024.000000  1.470000e+05  146206.000000
# 75%      2025.000000  1.990000e+05  198000.000000
# max      2025.000000  3.040000e+07  800000.000000

# %%
df.head()
# Out:
#       ano experiencia        contrato               cargo  salario moeda  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df.isnull().sum()
# Out:
# ano                10
# experiencia         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df["ano"].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano experiencia        contrato                      cargo  salario  \
# 5588    NaN      Sênior  Tempo Integral            Product Manager   184500
# 59692   NaN       pleno  Tempo Integral                   Engineer   110000
# 59710   NaN      Júnior  Tempo Integral             Data Scientist   208800
# 59759   NaN      Sênior  Tempo Integral          Software Engineer   135000
# 59789   NaN      Sênior  Tempo Integral                   Engineer   112000
# 131000  NaN      Sênior  Tempo Integral  Machine Learning Engineer   163800
# 131006  NaN      Sênior  Tempo Integral     Data Analytics Manager   204500
# 133054  NaN      Júnior  Tempo Integral             Data Scientist    40000
# 133281  NaN       pleno  Tempo Integral  Machine Learning Engineer   180000
# 133317  NaN       pleno  Tempo Integral             Data Scientist   130000
#
#        moeda     usd residencia      remoto empresa tamanho_empresa
# ...

# %% [markdown]
# # Aula 02: LIMPAR E PREPARAR DADOS

# %%
import numpy as np

# Criação de uma dataframe de teste

df_salarios = pd.DataFrame({
"nome":["Aline", "Almiro", "Claiton", "Filipa", "Duda"],
"salario":[4000, np.nan, 5000, np.nan, 100000]
 })

#calcula média salarial e substitui os nulos e arredonda os valores
df_salarios["salario_media"] = df_salarios["salario"].fillna(df_salarios["salario"].mean().round(2))


# Calcula a mediana salarial e substitui os nulos e arredonda os valores

df_salarios["salario_mediana"] = df_salarios["salario"].fillna(df_salarios["salario"].median())

df_salarios
# Out:
#       nome   salario  salario_media  salario_mediana
# 0    Aline    4000.0        4000.00           4000.0
# 1   Almiro       NaN       36333.33           5000.0
# 2  Claiton    5000.0        5000.00           5000.0
# 3   Filipa       NaN       36333.33           5000.0
# 4     Duda  100000.0      100000.00         100000.0

# %%
df_temperaturas = pd.DataFrame({
    "Dia": ["Segunda", "Terça", "Quarta", "Quinta", "Sexta"],
    "Temperatura": [30, np.nan, np.nan, 28, 27]

    })

df_temperaturas["Preencido_ffill"] = df_temperaturas["Temperatura"].ffill()
df_temperaturas
# Out:
#        Dia  Temperatura  Preencido_ffill
# 0  Segunda         30.0             30.0
# 1    Terça          NaN             30.0
# 2   Quarta          NaN             30.0
# 3   Quinta         28.0             28.0
# 4    Sexta         27.0             27.0

# %%
df_temperaturas = pd.DataFrame({
    "Dia": ["Segunda", "Terça", "Quarta", "Quinta", "Sexta"],
    "Temperatura": [30, np.nan, np.nan, 28, 27]

    })

df_temperaturas["Preencido_bfill"] = df_temperaturas["Temperatura"].bfill()
df_temperaturas
# Out:
#        Dia  Temperatura  Preencido_bfill
# 0  Segunda         30.0             30.0
# 1    Terça          NaN             28.0
# 2   Quarta          NaN             28.0
# 3   Quinta         28.0             28.0
# 4    Sexta         27.0             27.0

# %%
df_cidades = pd.DataFrame ({
"nome": ["Aline", "Almiro", "Claiton", "Filipa", "Duda"],
 "cidade": ["Lobito", np.nan, "Benguela", np.nan, "Catumbela"]
})

df_cidades["Cidade_Preenchida"] = df_cidades["cidade"].fillna("Não Informado")
df_cidades
# Out:
#       nome     cidade Cidade_Preenchida
# 0    Aline     Lobito            Lobito
# 1   Almiro        NaN     Não Informado
# 2  Claiton   Benguela          Benguela
# 3   Filipa        NaN     Não Informado
# 4     Duda  Catumbela         Catumbela

# %%
df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# ano                0
# experiencia        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano experiencia        contrato               cargo  salario moeda  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   experiencia      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
#Converter o tipo de dado de float64 para int64

df_limpo = df_limpo.assign(ano = df_limpo["ano"].astype("int64"))
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  int64
#  1   experiencia      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 12.2+ MB

# %% [markdown]
# # AULA 03 - CRIAÇÃO DE GÁFICOS

# %%
df_limpo.head()
# Out:
#     ano experiencia        contrato               cargo  salario moeda  \
# 0  2025      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df_limpo['experiencia'].value_counts().plot(kind='bar', title = 'Distribuição de Experiência')
# Out:
# <Axes: title={'center': 'Distribuição de Experiência'}, xlabel='experiencia'>

# %%
import seaborn as sns

# %%
sns.barplot(data=df_limpo, x="experiencia", y="usd")
# Out:
# <Axes: xlabel='experiencia', ylabel='usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x="experiencia", y="usd")
plt.title("Salário Médio por Experiência")
plt.xlabel("Experiência")
plt.ylabel("Salário Médio Anual (USD)")
plt.show()

# %%
from ast import Assign
df_limpo.groupby("experiencia")["usd"].mean().sort_values(ascending=False)
# Out:
# experiencia
# Executivo    202027.667813
# Sênior       172850.838301
# pleno        143044.845979
# Júnior        99034.963267
# Name: usd, dtype: float64

# %%
ordem = df_limpo.groupby("experiencia")["usd"].mean().sort_values(ascending=True).index
ordem
# Out:
# Index(['Júnior', 'pleno', 'Sênior', 'Executivo'], dtype='object', name='experiencia')

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x="experiencia", y="usd", order=ordem)
plt.title("Salário Médio por Experiência")
plt.xlabel("Experiência")
plt.ylabel("Salário Médio Anual (USD)")
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.histplot(df_limpo ["usd"], bins=50, kde=True)
plt.title("Distribuição dos Salários Anuais")
plt.xlabel("Salário em USD")
plt.ylabel("Frequência")
plt.show()

# %%
from re import X
plt.figure(figsize = (8,5))
sns.boxplot(x=df_limpo["usd"])
plt.title("Boxplot Salário")
plt.xlabel("Salário em USD")
plt.show()

# %%
ordem_experiencia = ["Júnior", "pleno", "Sênior", "Executivo"]
plt.figure(figsize = (8,5))
sns.boxplot(x="experiencia", y= "usd", data=df_limpo, order=ordem_experiencia)
plt.title("Boxplot da Distribuição por Experiência")
plt.xlabel("Experiência")
plt.ylabel("Salário em USD")
plt.show()

# %%
ordem_experiencia = ["Júnior", "pleno", "Sênior", "Executivo"]

plt.figure(figsize = (8,5))
sns.boxplot(x="experiencia", y= "usd", data=df_limpo, order=ordem_experiencia, palette="Set2", hue="experiencia")
plt.title("Boxplot da Distribuição por Experiência")
plt.xlabel("Experiência")
plt.ylabel("Salário em USD")
plt.show()

# %%
import plotly.express as px

# %%
df_media_sal_experiencia = df_limpo.groupby('experiencia')['usd'].mean().reindex(ordem_experiencia).reset_index()
fig = px.bar(
    df_media_sal_experiencia,
    x='experiencia',
    y='usd',
    title='Média Salarial por Nível de Experiência',
    labels={'experiencia': 'Nível de Experiência', 'usd': 'Média Salarial Anual (USD)'},
    color='experiencia', # Para diferenciar as barras por cor
    color_discrete_sequence=px.colors.qualitative.Set2 # Usando uma paleta de cores agradável
)
fig.update_layout(xaxis={'categoryorder':'array', 'categoryarray': ordem_experiencia})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagens = df_limpo['remoto'].value_counts().reset_index()
remoto_contagens.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(
    remoto_contagens,
   names='tipo_trabalho',
   values='quantidade',
   title='Proporção dos Tipo de Trabalho'

  )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagens = df_limpo['remoto'].value_counts().reset_index()
remoto_contagens.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(
    remoto_contagens,
   names='tipo_trabalho',
   values='quantidade',
   title='Proporção dos Tipo de Trabalho',
    hole=0.5

  )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagens = df_limpo['remoto'].value_counts().reset_index()
remoto_contagens.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(
    remoto_contagens,
   names='tipo_trabalho',
   values='quantidade',
   title='Proporção dos Tipo de Trabalho',
    hole=0.5

  )

fig.update_traces(textinfo="percent+label")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_data_scientist = df_limpo[df_limpo['cargo'] == 'Data Scientist']
df_avg_salary_ds_country = df_data_scientist.groupby('residencia')['usd'].mean().sort_values(ascending=False).reset_index()

fig = px.bar(
    df_avg_salary_ds_country,
    x='residencia',
    y='usd',
    title='Média Salarial Anual de Cientistas de Dados por País',
    labels={'residencia': 'País de Residência do Funcionário', 'usd': 'Média Salarial Anual (USD)'},
    color='residencia', # Color by country
    color_discrete_sequence=px.colors.qualitative.Pastel # Using a different color palette for variety
)
fig.update_layout(xaxis_title_standoff=25)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## AULA 4 - DASHBOARD INTERATIVO

# %%
pip install pycountry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 44.9 MB/s eta 0:00:00
# ...

# %%
import pycountry

# %%
import pycountry

# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.head()
# Out:
#     ano experiencia        contrato               cargo  salario moeda  \
# 0  2025      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa residencia_iso3
# 0  214000         US      Remoto      US           Médio             USA
# 1  136000         US      Remoto      US           Médio             USA
# 2  158800         AU  Presencial      AU           Médio             AUS
# 3  139200         AU  Presencial      AU           Médio             AUS
# 4   90000         US  Presencial      US           Médio             USA

# %%
df_limpo.to_csv("Dados-Imersão-final.csv", index=False)
